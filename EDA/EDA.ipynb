# %% [markdown]
# EDA- Exploratory data analysis
#
# It is the process of analyzing and understanding a dataset before building any model. It is understanding your data deeply using stastics and visualization before modeling.
#
# Like:
# what data I have
# is that data clean
# what pattern exist
# Are there trends or relationships
# any anomolies or outliers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
